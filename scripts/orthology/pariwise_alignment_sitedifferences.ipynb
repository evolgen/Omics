# %% [markdown]
# # Comparing MSA for differences in alignment - first for two alone

# %%
#!/usr/bin/env python3

import sys
from Bio import SeqIO
import decimal
import collections

#if len(sys.argv) != 2:
#    print("Please call one input file")
#    sys.exit()

#record_dict = SeqIO.to_dict(SeqIO.parse(sys.argv[1], 'fasta'))
#file_name1 = sys.argv[1]
#orthogroup1 = file_name1[file_name1.find('OrthoGroup'):].split('.')[0]


record_dict = SeqIO.to_dict(SeqIO.parse('/global/scratch2/rohitkolora/Rockfish/Genomes/Provean/long_PSG_dnarepairGO/sorted.OrthoGroup1116.FAA', 'fasta'))
file_name1 = "/global/scratch2/rohitkolora/Rockfish/Genomes/Provean/long_PSG_dnarepairGO/sorted.OrthoGroup1116.FAA"
orthogroup1 = file_name1[file_name1.find('OrthoGroup'):].split('.')[0]

all_species =  list([*record_dict])

seq_lengths1 = [len(val1) for val1 in record_dict.values()]
uniq_seq_lengths = sorted(set(seq_lengths1))
size_uniq_seq_lengths = len(uniq_seq_lengths)
if(size_uniq_seq_lengths != 1):
    sys.exit (' The sequences must be an MSA of equal length')

if(len(all_species) != 2):
    sys.exit (' We need atleast two-sequences MSA first')
    
first_species = list(record_dict.keys())[0]
align_length1 = len(record_dict[first_species])

#print(first_species, align_length1)

curr_seq_dict = dict([(x1,record_dict[x1]) for x1 in list(record_dict.keys())])

seqnames1 = "\t".join(list(curr_seq_dict.keys()))

human_description = list(curr_seq_dict.items())[0][-1].description
human_description = human_description[human_description.find(' GN='):]
gene_name = human_description.split(" ")[1].replace("GN=","")

print("#Gene", "OrthoGroup", "Human_seq", "Rockfish_seq", 
      "Human_AA", "Rockfish_AA", "Aln_pos", "Human_pos", 
      "Provean_input", sep="\t")

actual_position = 0
for curr_base in range(0, align_length1-1):
    curr_base_exact = curr_base + 1
    list_curr_base_seq = []
    count_curr_base_seq = {}
#    meta_base_seq_counts_seqs[curr_base_exact] = {}
    for key1, value1 in curr_seq_dict.items():
        list_curr_base_seq.append(curr_seq_dict[key1][curr_base])
    human_pos_exact = list(list_curr_base_seq[0])    
    if "-" not in human_pos_exact:
        actual_position = actual_position + 1     
    if "-" in list(list_curr_base_seq):
        continue
    if len(sorted(set(list_curr_base_seq))) == 1:
        continue
    provean_currbase = str(list_curr_base_seq[0]) + str(actual_position) + str(list_curr_base_seq[1])    
    print(gene_name, orthogroup1, seqnames1, list_curr_base_seq[0], list_curr_base_seq[1], 
          curr_base_exact, actual_position, 
          provean_currbase, sep="\t")
# Out:
# #Gene	OrthoGroup	Human_seq	Rockfish_seq	Human_AA	Rockfish_AA	Aln_pos	Human_pos	Provean_input
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	D	43	2	V2D
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	P	46	5	V5P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	H	K	48	7	H7K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	T	49	8	K8T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	V	51	10	P10V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	Q	E	56	15	Q15E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	F	A	57	16	F16A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	K	58	17	D17K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	H	E	59	18	H18E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	D	62	19	S19D
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	D	64	21	S21D
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	E	66	23	D23E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	A	69	26	V26A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	C	70	27	S27C
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	V	71	28	A28V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	T	R	72	29	T29R
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	P	73	30	V30P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	L	P	75	32	L32P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	N	S	76	33	N33S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	A	79	36	S36A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	T	D	81	38	T38D
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	V	82	39	A39V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	K	83	40	P40K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	Q	84	41	K41Q
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	L	H	86	43	L43H
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	Q	K	88	45	Q45K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	S	89	46	D46S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	S	90	47	K47S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	S	91	48	P48S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	S	93	50	P50S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	N	S	94	51	N51S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	S	105	62	V62S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	S	108	65	K65S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	T	N	109	66	T66N
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	S	110	67	P67S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	Q	111	68	K68Q
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	S	112	69	K69S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	R	T	113	70	R70T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	S	115	72	P72S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	E	Q	116	73	E73Q
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	G	K	117	74	G74K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	Q	S	210	167	Q167S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	G	R	211	168	G168R
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	Q	212	169	K169Q
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	G	216	173	A173G
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	A	217	174	S174A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	R	218	175	K175R
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	T	220	177	A177T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	E	221	178	A178E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	Q	E	222	179	Q179E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	R	K	224	181	R181K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	I	K	226	183	I183K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	T	231	188	S188T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	E	235	192	S192E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	D	236	193	A193D
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	N	E	237	194	N194E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	T	Y	239	196	T196Y
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	K	242	199	D199K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	F	L	243	200	F200L
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	T	244	201	A201T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	E	248	205	D205E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	E	D	250	207	E207D
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	E	254	210	S210E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	C	S	257	213	C213S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	A	260	215	S215A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	S	262	217	D217S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	N	E	263	218	N218E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	E	266	221	D221E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	T	268	223	S223T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	M	V	269	224	M224V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	R	K	270	225	R225K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	S	275	230	K230S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	E	K	276	231	E231K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	I	T	277	232	I232T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	K	282	237	V237K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	V	283	238	K238V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	T	284	239	V239T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	N	286	241	S241N
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	E	S	295	244	E244S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	E	300	249	K249E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	P	301	250	S250P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	S	302	251	K251S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	K	303	252	S252K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	P	304	253	K253P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	A	313	262	D262A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	V	315	264	A264V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	V	317	266	A266V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	R	318	267	A267R
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	S	319	268	V268S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	P	320	269	K269P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	P	321	270	S270P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	E	T	322	271	E271T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	A	323	272	S272A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	Q	E	324	273	Q273E
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	L	325	274	S274L
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	L	A	326	275	L275A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	R	329	278	K278R
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	V	P	330	279	V279P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	A	331	280	S280A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	L	S	332	281	L281S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	D	T	335	284	D284T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	T	V	336	285	T285V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	T	S	337	286	T286S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	R	T	338	287	R287T
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	K	L	339	288	K288L
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	K	340	289	P289K
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	L	P	341	290	L290P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	E	A	342	291	E291A
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	I	L	343	292	I292L
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	R	S	344	293	R293S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	P	345	294	S294P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	P	S	346	295	P295S
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	P	347	296	S296P
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	N	G	380	329	N329G
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	S	G	382	331	S331G
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	L	R	390	339	L339R
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	A	V	391	340	A340V
# RAD51AP1	OrthoGroup1116	sp|Q96B01|R51A1_HUMAN	Sebastes_ruberrimus	N	S	399	348	N348S

# %%
print(file_name1.split("/")[-1])
print(file_name1[file_name1.find('OrthoGroup'):].split('.')[0])
#print(human_description.replace('.* GN=', human_description))
list(list_curr_base_seq[0])
# Out:
# sorted.OrthoGroup1116.FAA
# OrthoGroup1116
# ['K']
